# %%
import numpy as np
import matplotlib.pyplot as plot

# %%
benchmark_accuracy = [1.0, 1.0, 0.875, 0.875, 0.937500, 0.937500, 1.000000, 1.000000, 0.875000, 0.875000, 0.750000, 1.000000, 0.937500, 0.937500, 0.750000, 0.875000, 0.750000, 0.875000, 0.937500, 0.875000, 0.875000, 0.750000, 0.937500, 0.75000, 0.812500]
benchmark_loss = [0.985722, 1.260806, 1.1307385, 1.013956, 0.958725, 0.957914, 1.156125, 0.677843, 1.473790, 1.108234, 0.948266, 0.738301, 0.892717, 0.727212, 0.961459, 1.002946, 1.119781, 1.015972, 1.280352, 1.074089, 1.150679, 1.304661, 1.007569, 1.533647, 1.023713]

# %%
test_loss = np.loadtxt('cls/cls_test_loss_5.out')
train_loss = np.loadtxt('cls/cls_train_loss_5.out')
test_acc = np.loadtxt('cls/cls_test_acc_5.out')
train_acc = np.loadtxt('cls/cls_train_acc_5.out')

# %%
print(test_loss)
# Out:
# [2.77238774 2.73840046 2.58042693 2.14289975 1.91520107 1.62073481
#  1.61935782 2.03749156 1.39854765 1.21408689 1.36200154 1.39776289
#  1.35756207 1.43098557 1.16815937 1.18982446 1.28760076 1.37245131
#  1.34001493 1.20127904 1.6030674  1.21336675 1.26266825 1.40306628
#  1.23800719 1.32257879 1.5425483  1.50031698 1.32460809 1.2994206
#  1.22780418 1.36904585 1.38781548 1.49714148 1.37954664 1.17308736
#  1.09789062 1.21498334 1.43280566 1.22688711 1.51748598 1.22704315
#  1.23960662 1.24475396 1.59679174 0.93537664 1.21609199 1.34438682
#  1.41560888 1.15070832 1.79134929 1.35590863 1.48157513 1.20734918
#  1.11159503 0.86881518 1.61960769 1.43078625 1.01203203 1.347103
#  1.41682243 1.07116508 1.42034304 1.10352731 1.20389414 1.11759484
#  1.18943787 1.54094493 1.23070252 1.27757692 1.39750254 1.42423093
#  1.34450805 1.59488332 1.21690679 1.34881163 1.11223578 1.13883078
#  1.28509605 1.31520247 1.05912578 1.62516308 1.03188479 0.86370337
# ...

# %%
train_x = np.linspace(0, 998 * 6, len(train_loss))
test_x = np.linspace(0, 998 * 6, len(test_loss))

cost = plot.figure()
plot.plot(train_x, train_loss)
plot.plot(test_x, test_loss)
plot.ylabel('cost')
plot.xlabel('iterations')

acc = plot.figure()
plot.plot(train_x, train_acc)
plot.plot(test_x, test_acc)
plot.ylabel('accuracy')
plot.xlabel('iterations')
# Out:
# Text(0.5,0,'iterations')

# %%
cost.savefig('benchmark_cls_cost_6.png')
acc.savefig('benchmark_cls_acc_6.png')
